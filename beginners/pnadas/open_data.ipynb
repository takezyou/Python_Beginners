# %% [markdown]
# # Pandasでオープンデータを扱おう

# %%
# pandasの読み込み
import pandas as pd

# %% [markdown]
# ### 横浜市統計ポータルサイト
# http://www.city.yokohama.lg.jp/ex/stat/opendata/suikei01.html

# %%
# オープンデータのURL
open_data = "http://www.city.yokohama.lg.jp/ex/stat/opendata/suikei01/e1yokohama1608.csv"

# %%
open_data
# Out:
# 'http://www.city.yokohama.lg.jp/ex/stat/opendata/suikei01/e1yokohama1608.csv'

# %%
# データの読み込み
df = pd.read_csv(open_data, index_col='市区名')

# %%
# データを表示
df
# Out:
#            ﻿年月日  全国地方公共団体コード  面積［平方キロメートル］  世帯数［世帯］  人口総数［人］     男［人］  \
# 市区名
# 横浜市    2016/8/1       141003        435.29  1659203  3732609  1857557
# 鶴見区    2016/8/1       141011         32.38   134398   287126   148467
# 神奈川区   2016/8/1       141020         23.59   120443   239904   122103
# 西区     2016/8/1       141038          6.98    51997    98821    49974
# 中区     2016/8/1       141046         20.93    79370   148847    78203
# 南区     2016/8/1       141054         12.63    96349   195021    96975
# 港南区    2016/8/1       141119         19.86    91517   215030   105573
# 保土ケ谷区  2016/8/1       141062         21.81    93881   206450   102698
# 旭区     2016/8/1       141127         32.78   103479   247072   120054
# 磯子区    2016/8/1       141071         19.02    75373   166824    82122
# 金沢区    2016/8/1       141089         30.68    87377   201614    98727
# 港北区    2016/8/1       141097         31.37   164745   346263   175226
# 緑区     2016/8/1       141135         25.42    75317   181094    89194
# 青葉区    2016/8/1       141178         35.06   126641   310435   151319
# 都筑区    2016/8/1       141186         27.88    81369   212344   106168
# 戸塚区    2016/8/1       141101         35.70   114365   275713   135229
# 栄区     2016/8/1       141151         18.55    50669   121791    59535
# 泉区     2016/8/1       141160         23.56    61191   153981    75289
# 瀬谷区    2016/8/1       141143         17.11    50722   124279    60701
#
#           女［人］  １世帯当たり人員［人］  人口密度［人／平方キロメートル］  届出による前月比増減の世帯数［世帯］  \
# 市区名
# 横浜市    1875052         2.25              8575                -143
# 鶴見区     138659         2.14              8867                 -23
# 神奈川区    117801         1.99             10170                -156
# 西区       48847         1.90             14158                 -28
# 中区       70644         1.88              7112                  49
# 南区       98046         2.02             15441                   2
# 港南区     109457         2.35             10827                  15
# 保土ケ谷区   103752         2.20              9466                  27
# 旭区      127018         2.39              7537                  70
# 磯子区      84702         2.21              8771                  53
# 金沢区     102887         2.31              6572                   2
# 港北区     171037         2.10             11038                -166
# 緑区       91900         2.40              7124                  36
# 青葉区     159116         2.45              8854                  71
# 都筑区     106176         2.61              7616                 -39
# 戸塚区     140484         2.41              7723                 -21
# 栄区       62256         2.40              6566                 -68
# 泉区       78692         2.52              6536                  17
# 瀬谷区      63578         2.45              7264                  16
#
#        届出による前月比増減の人口［人］
# 市区名
# 横浜市                -464
# 鶴見区                  55
# 神奈川区               -233
# 西区                   -4
# 中区                   64
# 南区                   86
# 港南区                 -45
# 保土ケ谷区                39
# 旭区                   45
# 磯子区                  35
# 金沢区                 -33
# 港北区                -207
# 緑区                   97
# 青葉区                  38
# 都筑区                -230
# 戸塚区                 -40
# 栄区                 -155
# 泉区                   14
# 瀬谷区                  10

# %%
# カラム名の変更
df.rename(columns={'全国地方公共団体コード':'Code'}, inplace=True)

# %%
df
# Out:
#            ﻿年月日    Code  面積［平方キロメートル］  世帯数［世帯］  人口総数［人］     男［人］     女［人］  \
# 市区名
# 横浜市    2016/8/1  141003        435.29  1659203  3732609  1857557  1875052
# 鶴見区    2016/8/1  141011         32.38   134398   287126   148467   138659
# 神奈川区   2016/8/1  141020         23.59   120443   239904   122103   117801
# 西区     2016/8/1  141038          6.98    51997    98821    49974    48847
# 中区     2016/8/1  141046         20.93    79370   148847    78203    70644
# 南区     2016/8/1  141054         12.63    96349   195021    96975    98046
# 港南区    2016/8/1  141119         19.86    91517   215030   105573   109457
# 保土ケ谷区  2016/8/1  141062         21.81    93881   206450   102698   103752
# 旭区     2016/8/1  141127         32.78   103479   247072   120054   127018
# 磯子区    2016/8/1  141071         19.02    75373   166824    82122    84702
# 金沢区    2016/8/1  141089         30.68    87377   201614    98727   102887
# 港北区    2016/8/1  141097         31.37   164745   346263   175226   171037
# 緑区     2016/8/1  141135         25.42    75317   181094    89194    91900
# 青葉区    2016/8/1  141178         35.06   126641   310435   151319   159116
# 都筑区    2016/8/1  141186         27.88    81369   212344   106168   106176
# 戸塚区    2016/8/1  141101         35.70   114365   275713   135229   140484
# 栄区     2016/8/1  141151         18.55    50669   121791    59535    62256
# 泉区     2016/8/1  141160         23.56    61191   153981    75289    78692
# 瀬谷区    2016/8/1  141143         17.11    50722   124279    60701    63578
#
#        １世帯当たり人員［人］  人口密度［人／平方キロメートル］  届出による前月比増減の世帯数［世帯］  届出による前月比増減の人口［人］
# 市区名
# 横浜市           2.25              8575                -143              -464
# 鶴見区           2.14              8867                 -23                55
# 神奈川区          1.99             10170                -156              -233
# 西区            1.90             14158                 -28                -4
# 中区            1.88              7112                  49                64
# 南区            2.02             15441                   2                86
# 港南区           2.35             10827                  15               -45
# 保土ケ谷区         2.20              9466                  27                39
# 旭区            2.39              7537                  70                45
# 磯子区           2.21              8771                  53                35
# 金沢区           2.31              6572                   2               -33
# 港北区           2.10             11038                -166              -207
# 緑区            2.40              7124                  36                97
# 青葉区           2.45              8854                  71                38
# 都筑区           2.61              7616                 -39              -230
# 戸塚区           2.41              7723                 -21               -40
# 栄区            2.40              6566                 -68              -155
# 泉区            2.52              6536                  17                14
# 瀬谷区           2.45              7264                  16                10

# %%
df.tail(3)
# Out:
#          ﻿年月日    Code  面積［平方キロメートル］  世帯数［世帯］  人口総数［人］   男［人］   女［人］  \
# 市区名
# 栄区   2016/8/1  141151         18.55    50669   121791  59535  62256
# 泉区   2016/8/1  141160         23.56    61191   153981  75289  78692
# 瀬谷区  2016/8/1  141143         17.11    50722   124279  60701  63578
#
#      １世帯当たり人員［人］  人口密度［人／平方キロメートル］  届出による前月比増減の世帯数［世帯］  届出による前月比増減の人口［人］
# 市区名
# 栄区          2.40              6566                 -68              -155
# 泉区          2.52              6536                  17                14
# 瀬谷区         2.45              7264                  16                10

# %%
# 解析対象とする列の名前を指定
key_data = ['人口総数［人］', '男［人］', '女［人］']

# %%
# 横浜市(Code: 141003)を解析対象から除外し、新しいデータフレームを作る
pp = df[df.Code!=141003][key_data]

# %%
pp
# Out:
#        人口総数［人］    男［人］    女［人］
# 市区名
# 鶴見区     287126  148467  138659
# 神奈川区    239904  122103  117801
# 西区       98821   49974   48847
# 中区      148847   78203   70644
# 南区      195021   96975   98046
# 港南区     215030  105573  109457
# 保土ケ谷区   206450  102698  103752
# 旭区      247072  120054  127018
# 磯子区     166824   82122   84702
# 金沢区     201614   98727  102887
# 港北区     346263  175226  171037
# 緑区      181094   89194   91900
# 青葉区     310435  151319  159116
# 都筑区     212344  106168  106176
# 戸塚区     275713  135229  140484
# 栄区      121791   59535   62256
# 泉区      153981   75289   78692
# 瀬谷区     124279   60701   63578

# %%
# 描画用モジュールの呼び出し
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
# 描画用の日本語フォントを指定
from matplotlib import rc
font = {'family':'Osaka'}
rc('font', **font)

# %%
# 各市区に住む男女数を棒グラフで表示
pp.plot(kind='bar', figsize=(12,6), y=['男［人］', '女［人］'], fontsize=17)

# %%
# 各市区の人口総数で並べ替え、新しいデータフレームを作成
sorted_pp = pp.sort_values(by="人口総数［人］", ascending=False)

# %%
sorted_pp
# Out:
#        人口総数［人］    男［人］    女［人］
# 市区名
# 港北区     346263  175226  171037
# 青葉区     310435  151319  159116
# 鶴見区     287126  148467  138659
# 戸塚区     275713  135229  140484
# 旭区      247072  120054  127018
# 神奈川区    239904  122103  117801
# 港南区     215030  105573  109457
# 都筑区     212344  106168  106176
# 保土ケ谷区   206450  102698  103752
# 金沢区     201614   98727  102887
# 南区      195021   96975   98046
# 緑区      181094   89194   91900
# 磯子区     166824   82122   84702
# 泉区      153981   75289   78692
# 中区      148847   78203   70644
# 瀬谷区     124279   60701   63578
# 栄区      121791   59535   62256
# 西区       98821   49974   48847

# %%
# 並べ替えしたデータを表示
sorted_pp.plot(kind='bar', figsize=(12,6), y=['男［人］', '女［人］'], fontsize=17)
